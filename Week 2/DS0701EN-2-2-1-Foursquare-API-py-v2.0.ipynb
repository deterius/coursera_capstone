# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/labs_v1/IDSNlogo.png" width = 400> </a>
#
# <h1 align=center><font size = 5>Learning FourSquare API with Python</font></h1>

# %% [markdown]
# ## Introduction
#
# In this lab, you will learn in details how to make calls to the Foursquare API for different purposes. You will learn how to construct a URL to send a request to the API to search for a specific type of venues, to explore a particular venue, to explore a Foursquare user, to explore a geographical location, and to get trending venues around a location. Also, you will learn how to use the visualization library, Folium, to visualize the results.

# %% [markdown]
# ## Table of Contents
#
# 1.  <a href="#item1">Foursquare API Search Function</a>
# 2.  <a href="#item2">Explore a Given Venue</a>
# 3.  <a href="#item3">Explore a User</a>
# 4.  <a href="#item4">Foursquare API Explore Function</a>
# 5.  <a href="#item5">Get Trending Venues</a>

# %% [markdown]
# ### Import necessary Libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize



import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Requirement already satisfied: geopy in /Users/simeonbourim/.pyenv/versions/3.7.3/Python.framework/Versions/3.7/lib/python3.7/site-packages (2.1.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /Users/simeonbourim/.pyenv/versions/3.7.3/Python.framework/Versions/3.7/lib/python3.7/site-packages (from geopy) (1.52)
# WARNING: You are using pip version 21.1.2; however, version 21.1.3 is available.
# You should consider upgrading via the '/Users/simeonbourim/.pyenv/versions/3.7.3/Python.framework/Versions/3.7/bin/python3.7 -m pip install --upgrade pip' command.
# Folium installed
# Libraries imported.

# %% [markdown]
# ### Define Foursquare Credentials and Version

# %% [markdown]
# ##### Make sure that you have created a Foursquare developer account and have your credentials handy

# %% [markdown]
# ##### To obtain access token follow these steps.
#
# <br>
#
# 1.  Go to your **"App Settings"** page on the developer console of Foursquare.com
# 2.  Set the **"Redirect URL"** under **"Web Addresses"** to [https://www.google.com](https://www.google.com?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork-21253531&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork-21253531&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork-21253531&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork-21253531&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork-21253531&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork-21253531&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
#
# 3.  Paste and enter the following url in your web browser **(replace YOUR_CLIENT_ID with your actual client id)**:
#     [https://foursquare.com/oauth2/authenticate?client_id=YOUR_CLIENT_ID&response_type=code&redirect_uri=https://www.google.com](https://foursquare.com/oauth2/authenticate?client_id=YOUR_CLIENT_ID&response_type=code&redirect_uri=https://www.google.com&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork-21253531&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
#     This should redirect you to a google page requesting permission to make the connection.
# 4.  Accept and then look at the url of your web browser **(take note at the CODE part of the url to use in step 5)**
#     It should look like [https://www.google.com/?code=CODE](https://www.google.com?code=CODE&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork-21253531&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
# 5.  Copy the code value from the previous step.
#        Paste and enter the following into your web browser **(replace placeholders with actual values)**:
#     [https://foursquare.com/oauth2/access_token?client_id=YOUR_CLIENT_ID&client_secret=YOUR_CLIENT_SECRET&grant_type=authorization_code&redirect_uri=https://www.google.com&code=CODE](https://foursquare.com/oauth2/access_token?client_id=YOUR_CLIENT_ID&client_secret=YOUR_CLIENT_SECRET&grant_type=authorization_code&redirect_uri=https://www.google.com&code=CODE&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork-21253531&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
# 6.  When you paste the link , This should lead you to a page that gives you your **access token**.

# %%
#  https://foursquare.com/oauth2/authenticate?client_id=EZH4ERBYQUEFWGXF300Z2F2MGAVYER22QXQL50PBV4PTO02B&response_type=code&redirect_uri=https://www.google.com

# code: https://www.google.com/?code=RHVRTQMLNIV31NKIUSFRJP43VH1D5ETCM5QDNUYKLFMCYZ50#_=_

# https://foursquare.com/oauth2/access_token?client_id=EZH4ERBYQUEFWGXF300Z2F2MGAVYER22QXQL50PBV4PTO02B&client_secret=EJV41SURWZJNTRURBKEPEXQRT0JWWAOELP50MPUJHKBQSSBL&grant_type=authorization_code&redirect_uri=https://www.google.com&code=RHVRTQMLNIV31NKIUSFRJP43VH1D5ETCM5QDNUYKLFMCYZ50#_=_

# {"access_token":"FRPG1SFDQVXC4OJYK22I00XLLZO0ZTNDNV4RP5XE3N4KPFFL"}



CLIENT_ID = 'EZH4ERBYQUEFWGXF300Z2F2MGAVYER22QXQL50PBV4PTO02B' # your Foursquare ID
CLIENT_SECRET = 'EJV41SURWZJNTRURBKEPEXQRT0JWWAOELP50MPUJHKBQSSBL' # your Foursquare Secret
ACCESS_TOKEN = 'FRPG1SFDQVXC4OJYK22I00XLLZO0ZTNDNV4RP5XE3N4KPFFL' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: EZH4ERBYQUEFWGXF300Z2F2MGAVYER22QXQL50PBV4PTO02B
# CLIENT_SECRET:EJV41SURWZJNTRURBKEPEXQRT0JWWAOELP50MPUJHKBQSSBL

# %% [markdown]
# #### Let's again assume that you are staying at the Conrad hotel. So let's start by converting the Contrad Hotel's address to its latitude and longitude coordinates.

# %% [markdown]
# In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent <em>foursquare_agent</em>, as shown below.

# %%
# address = '102 North End Ave, New York, NY'

# geolocator = Nominatim(user_agent="foursquare_agent")
# location = geolocator.geocode(address)
# latitude = location.latitude
# longitude = location.longitude
# print(latitude, longitude)


#shanghai 
latitude = 31.220077760283953
longitude = 121.45089366101433
print(latitude, longitude)



# geolocator = Nominatim(user_agent='foursquare_agent')
# location = geolocator.geocode(address)
# latitude = location.latitude
# longitude = location.longitude
# print(latitude, longitude)
# Out:
# 31.220077760283953 121.45089366101433

# %% [markdown]
# <a id="item1"></a>

# %% [markdown]
# ## 1. Search for a specific venue category
#
# > `https://api.foursquare.com/v2/venues/`**search**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**`&query=`**QUERY**`&radius=`**RADIUS**`&limit=`**LIMIT**

# %% [markdown]
# #### Now, let's assume that it is lunch time, and you are craving Italian food. So, let's define a query to search for Italian food that is within 500 metres from the Conrad Hotel.

# %%
# search_query = 'Italian'
# radius = 500
# print(search_query + ' .... OK!')
search_query = 'kebab'
radius = 1500
print(search_query + ' ... ok!' )
# Out:
# kebab ... ok!

# %% [markdown]
# #### Define the corresponding URL

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=EZH4ERBYQUEFWGXF300Z2F2MGAVYER22QXQL50PBV4PTO02B&client_secret=EJV41SURWZJNTRURBKEPEXQRT0JWWAOELP50MPUJHKBQSSBL&ll=31.236084347642237,121.43121705362691&oauth_token=FRPG1SFDQVXC4OJYK22I00XLLZO0ZTNDNV4RP5XE3N4KPFFL&v=20180604&query=kebab&radius=1500&limit=30'

# %% [markdown]
# #### Send the GET Request and examine the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60e3b7bc28572c5d6c49152e'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'venues': []}}

# %% [markdown]
# #### Get relevant part of JSON and transform it into a _pandas_ dataframe

# %%
# # assign relevant part of JSON to venues
# venues = results['response']['venues']

# # tranform venues into a dataframe
# dataframe = pd.json_normalize(venues)
# dataframe.head()

venues = results['response']['venues']

dataframe = pd.json_normalize(venues)
dataframe.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Define information of interest and filter dataframe

# %%
# # keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name','categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# # # function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']

    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# # # filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# # # clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

# # dataframe_filtered
dataframe_filtered
# Out:
#                                       name                categories  \
# 0                   Brothers Kebab (兄弟烤肉店)          Kebab Restaurant
# 1                       Kebab Station (凯爸)        Turkish Restaurant
# 2                 Brothers Kebab (Julu758)      Fast Food Restaurant
# 3                              Doner Kebab        Turkish Restaurant
# 4                              Shish Kebab          Halal Restaurant
# 5                     Kebabs On The Grille         Indian Restaurant
# 6                                MF Kebabs  Mediterranean Restaurant
# 7  Oses Turkish Doner&Çiğ Köfte Tianzifang        Turkish Restaurant
#
#                                  address                      crossStreet  \
# 0                        310 Fengxian Rd                       Shaanxi Rd
# 1                  68 Yuyuan Rd | 愚园路68号  B2/F Crystal Galleria Mall | 晶品
# 2                                    NaN                              NaN
# 3            688 Changle Road // 长了路688号                Fumin Road // 富民路
# 4                               万航渡路109号                              NaN
# 5             113 Jiashan Road | 嘉善路113号             Yongkang Road | 近永康路
# 6                         50 Yongkang Rd                       Jiashan Rd
# 7  田子坊，泰康路248弄6号后门，地铁9号线打浦桥路站1号出口对面门进田子坊                              NaN
#
#          lat         lng                                     labeledLatLngs  \
# 0  31.230575  121.449861  [{'label': 'display', 'lat': 31.23057450778731...
# 1  31.227372  121.442378  [{'label': 'display', 'lat': 31.22737153917002...
# 2  31.220224  121.451260  [{'label': 'display', 'lat': 31.220224, 'lng':...
# 3  31.219841  121.448466  [{'label': 'display', 'lat': 31.21984102153703...
# 4  31.225187  121.442273  [{'label': 'display', 'lat': 31.225187, 'lng':...
# 5  31.212814  121.454528  [{'label': 'display', 'lat': 31.21281421602132...
# 6  31.213168  121.454072  [{'label': 'display', 'lat': 31.21316849046321...
# 7  31.209768  121.464179  [{'label': 'display', 'lat': 31.20976787643689...
#
#    distance  cc     city state country  \
# 0      1172  CN  Jing'an   上海市      中国
# 1      1147  CN  Jing'an   上海市      中国
# 2        38  CN      NaN   上海市      中国
# 3       232  CN      上海市   上海市      中国
# 4       998  CN      上海市   上海市      中国
# 5       879  CN    Xuhui   上海市      中国
# 6       826  CN      上海市   上海市      中国
# 7      1707  CN  Huangpu   上海市      中国
#
#                                     formattedAddress postalCode  \
# 0   [310 Fengxian Rd (Shaanxi Rd), Jing'an, 上海市, 中国]        NaN
# 1  [68 Yuyuan Rd | 愚园路68号 (B2/F Crystal Galleria ...     200040
# 2                         [Jìng'an, 上海市, 200023, 中国]     200023
# 3  [688 Changle Road // 长了路688号 (Fumin Road // 富民...        NaN
# 4                           [万航渡路109号, 上海市, 上海市, 中国]        NaN
# 5  [113 Jiashan Road | 嘉善路113号 (Yongkang Road | 近...        NaN
# 6        [50 Yongkang Rd (Jiashan Rd), 上海市, 上海市, 中国]        NaN
# 7  [田子坊，泰康路248弄6号后门，地铁9号线打浦桥路站1号出口对面门进田子坊, Huangp...        NaN
#
#      neighborhood                        id
# 0             NaN  53bf3589498e13b13a0f3156
# 1  Jìngʼān Temple  547f36fa498e7a801b49227f
# 2         Jìng'an  5eedcbed38abbd00089c2826
# 3             NaN  55e3efd1498e273c7c912fc9
# 4             NaN  5822e2081ff79651362afada
# 5             NaN  549d3f7b498ef56f91c837a4
# 6             NaN  52de01b0498e913d62507a01
# 7             NaN  52bfbcb5498e01893f30e662

# %% [markdown]
# #### Let's visualize the Italian restaurants that are nearby

# %%
dataframe_filtered.name
# Out:
# 0    Brothers Kebab (兄弟烤肉店)
# 1               Choco Kebab
# 2      Kebabs On The Grille
# Name: name, dtype: object

# %%
 # generate map centred around the Conrad Hotel
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13)

# # add a red circle marker to represent the Conrad Hotel


folium.CircleMarker(
    [latitude, longitude],
    raidus=10,
    color='red',
    popup='Shanghai',
    fill=True,
    fill_color='red',
    fill_opacity=0.6

).add_to(venues_map)

# # add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.name):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# # display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_cb01831cb7f04a5ea98fec13880765e7%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_cb01831cb7f04a5ea98fec13880765e7%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_cb01831cb7f04a5ea98fec13880765e7%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_cb01831cb7f04a5ea98fec13880765e7%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B31.220077760283953%2C121.45089366101433%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2013%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%2 ...

# %% [markdown]
# <a id="item2"></a>

# %% [markdown]
# ## 2. Explore a Given Venue
#
# > `https://api.foursquare.com/v2/venues/`**VENUE_ID**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&v=`**VERSION**

# %% [markdown]
# ### A. Let's explore the closest Italian restaurant -- _Harry's Italian Pizza Bar_

# %%
# venue_id = '4fa862b3e4b0ebff2f749f06' # ID of Harry's Italian Pizza Bar
venue_id = '5a30d9228b98fd39b756f91f' #BK
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/5a30d9228b98fd39b756f91f?client_id=EZH4ERBYQUEFWGXF300Z2F2MGAVYER22QXQL50PBV4PTO02B&client_secret=EJV41SURWZJNTRURBKEPEXQRT0JWWAOELP50MPUJHKBQSSBL&oauth_token=FRPG1SFDQVXC4OJYK22I00XLLZO0ZTNDNV4RP5XE3N4KPFFL&v=20180604'

# %% [markdown]
# #### Send GET request for result

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'likes', 'like', 'dislike', 'ok', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'hours', 'seasonalHours', 'defaultHours', 'pageUpdates', 'inbox', 'parent', 'hierarchy', 'attributes', 'bestPhoto'])
# {'id': '5a30d9228b98fd39b756f91f',
#  'name': 'Brothers Kebab (兄弟烤肉店)',
#  'contact': {'phone': '+862163131077',
#   'formattedPhone': '+86 21 6313 1077',
#   'facebook': '179569625563129',
#   'facebookUsername': 'brotherskebab',
#   'facebookName': 'Brothers Kebab'},
#  'location': {'address': '389 Nanjing W Rd\xa0 | 南京西路389号',
#   'crossStreet': 'B1/F Tomorrow Square',
#   'lat': 31.232508,
#   'lng': 121.46475,
#   'labeledLatLngs': [{'label': 'display', 'lat': 31.232508, 'lng': 121.46475}],
#   'cc': 'CN',
#   'city': 'Huangpu',
#   'state': '上海市',
#   'country': '中国',
#   'formattedAddress': ['389 Nanjing W Rd\xa0 | 南京西路389号 (B1/F Tomorrow Square)',
#    'Huangpu',
#    '上海市',
#    '中国']},
#  'canonicalUrl': 'https://foursquare.com/v/brothers-kebab-%E5%85%84%E5%BC%9F%E7%83%A4%E8%82%89%E5%BA%97/5a30d9228b98fd39b756f91f',
#  'categories': [{'id': '5283c7b4e4b094cb91ec88d7',
#    'name': 'Kebab Restaurant',
#    'pluralName': 'Kebab Restaurants',
#    'shortName': 'Kebab',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#     'suffix': '.png'},
#    'primary': True},
#   {'id': '4f04af1f2fb6e1c99f3db0bb',
#    'name': 'Turkish Restaurant',
#    'pluralName': 'Turkish Restaurants',
#    'shortName': 'Turkish',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#     'suffix': '.png'}},
#   {'id': '52e81612bcbc57f1066b79ff',
#    'name': 'Halal Restaurant',
#    'pluralName': 'Halal Restaurants',
#    'shortName': 'Halal',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/halal_',
#     'suffix': '.png'}}],
#  'verified': False,
#  'stats': {'tipCount': 1},
#  'url': 'http://brotherskebab.com',
#  'likes': {'count': 1,
#   'groups': [{'type': 'others',
#     'count': 1,
#     'items': [{'id': '475786006',
#       'firstName': 'Sana',
#       'lastName': 'Firdous',
#       'gender': 'female',
#       'countryCode': 'PK',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/475786006_kFTZ8P1j_d0mIVIOcm0gijyC6a5tENJ9cYnY1rpjpxucFjxJj4nV-amrxICPOWaTh_grxAtAI.jpg'}}]}],
#   'summary': 'Sana Firdous'},
#  'like': False,
#  'dislike': False,
#  'ok': False,
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 9,
#   'groups': [{'type': 'venue',
#     'name': 'Venue photos',
#     'count': 9,
#     'items': [{'id': '60685b0f58ba1d182d35ecd3',
#       'createdAt': 1617451791,
#       'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/8346567_IzkYGcru3e1gGdGKXFUjJwfY2wt2J3gIr2waHRh48E4.jpg',
#       'width': 1920,
#       'height': 1440,
#       'user': {'id': '8346567',
#        'firstName': 'Michael',
#        'lastName': 'Hakel',
#        'gender': 'male',
#        'countryCode': 'CN',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/8346567-GKZLGJG51BZ4KJCB.jpg'}},
#       'visibility': 'public'}]}]},
#  'reasons': {'count': 0, 'items': []},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1513150754,
#  'tips': {'count': 1,
#   'groups': [{'type': 'following',
#     'name': 'Tips from people you follow',
#     'count': 0,
#     'items': []},
#    {'type': 'others',
#     'name': 'All tips',
#     'count': 1,
#     'items': [{'id': '5b978380123a19002cf23c79',
#       'createdAt': 1536656256,
#       'text': 'If you are Muslim and want good junk food around do try doner wrap and chicken strips  its all  “HALAL”',
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/5b978380123a19002cf23c79',
#       'photo': {'id': '5b9772fdf427de0039d7ece9',
#        'createdAt': 1536652029,
#        'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'},
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/475786006_dKXKmgAusE8tuR_eYmmk8QuQzfMeZM6YKktyD8BEWRY.jpg',
#        'width': 1920,
#        'height': 1440,
#        'visibility': 'public'},
#       'photourl': 'https://fastly.4sqi.net/img/general/original/475786006_dKXKmgAusE8tuR_eYmmk8QuQzfMeZM6YKktyD8BEWRY.jpg',
#       'likes': {'count': 0, 'groups': []},
#       'like': False,
#       'logView': True,
#       'agreeCount': 0,
#       'disagreeCount': 0,
#       'todo': {'count': 0},
#       'user': {'id': '475786006',
#        'firstName': 'Sana',
#        'lastName': 'Firdous',
#        'gender': 'female',
#        'countryCode': 'PK',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/475786006_kFTZ8P1j_d0mIVIOcm0gijyC6a5tENJ9cYnY1rpjpxucFjxJj4nV-amrxICPOWaTh_grxAtAI.jpg'}},
#       'authorInteractionType': 'liked'}]}]},
#  'shortUrl': 'http://4sq.com/2iZbR1n',
#  'timeZone': 'Asia/Shanghai',
#  'listed': {'count': 2,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 2,
#     'items': [{'id': '59254a21e07550244e3b5ef6',
#       'name': 'Shanghai - Best Quick Eats',
#       'description': 'My personal favorites for quick bites or bringing the kids out',
#       'type': 'others',
#       'user': {'id': '404386804',
#        'firstName': 'Dave',
#        'lastName': 'Mc',
#        'gender': 'male',
#        'countryCode': 'CN',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/404386804_uMKVXWWK_G6wmGD2Kb18WmsxhBqymS0-fVU7QpXAv_PTJCzlKZ6JvwdKAwcK12D4pv2MfRe0l.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/foursquarechina/list/shanghai--best-quick-eats',
#       'canonicalUrl': 'https://foursquare.com/foursquarechina/list/shanghai--best-quick-eats',
#       'createdAt': 1495616033,
#       'updatedAt': 1624198325,
#       'photo': {'id': '5ac5c79d60d11b5457fcdea7',
#        'createdAt': 1522911133,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/404386804_sPJYFqWd4Qp-mSElZy13r_gfBPnFQQ_YnfmU0eGvL80.jpg',
#        'width': 1440,
#        'height': 1920,
#        'user': {'id': '404386804',
#         'firstName': 'Dave',
#         'lastName': 'Mc',
#         'gender': 'male',
#         'countryCode': 'CN',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/404386804_uMKVXWWK_G6wmGD2Kb18WmsxhBqymS0-fVU7QpXAv_PTJCzlKZ6JvwdKAwcK12D4pv2MfRe0l.jpg'}},
#        'visibility': 'public'},
#       'followers': {'count': 4},
#       'listItems': {'count': 66,
#        'items': [{'id': 'v5a30d9228b98fd39b756f91f',
#          'createdAt': 1577780116}]}},
#      {'id': '5cb5740b3b8307002c65f0c0',
#       'name': 'Shanghi',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '70929979',
#        'firstName': 'Naser',
#        'lastName': 'Altwaijri',
#        'gender': 'male',
#        'address': '',
#        'city': '',
#        'state': '',
#        'countryCode': 'SA',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/70929979_LGQd8VBh_NL-H4BkfzrRE49oc7Z98_hJviMbTxxCp6Gd26KEUokJKdz88CeV0hL1MTCHu9IxY.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/na9er_92/list/shanghi',
#       'canonicalUrl': 'https://foursquare.com/na9er_92/list/shanghi',
#       'createdAt': 1555395595,
#       'updatedAt': 1555809162,
#       'photo': {'id': '5c53e82435d3fc002c554860',
#        'createdAt': 1549002788,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/209700558_qWAibsZJ5SsrUf5BnlEsy4XZ1jfHDyyqBdSfXx2e8-w.jpg',
#        'width': 1440,
#        'height': 1920,
#        'user': {'id': '209700558',
#         'firstName': 'BQ',
#         'lastName': '^(oo)^',
#         'gender': 'female',
#         'countryCode': 'CN',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/209700558-L3HS2YSMDPUIIFMG.jpg'}},
#        'visibility': 'public'},
#       'followers': {'count': 0},
#       'listItems': {'count': 9,
#        'items': [{'id': 'v5a30d9228b98fd39b756f91f',
#          'createdAt': 1555766110}]}}]}]},
#  'hours': {'status': 'Open until 11:00 PM',
#   'richStatus': {'entities': [], 'text': 'Open until 11:00 PM'},
#   'isOpen': True,
#   'isLocalHoliday': False,
#   'dayData': [],
#   'timeframes': [{'days': 'Mon–Sun',
#     'includesToday': True,
#     'open': [{'renderedTime': '11:00 AM–11:00 PM'}],
#     'segments': []}]},
#  'seasonalHours': [],
#  'defaultHours': {'status': 'Open until 11:00 PM',
#   'richStatus': {'entities': [], 'text': 'Open until 11:00 PM'},
#   'isOpen': True,
#   'isLocalHoliday': False,
#   'dayData': [],
#   'timeframes': [{'days': 'Mon–Sun',
#     'includesToday': True,
#     'open': [{'renderedTime': '11:00 AM–11:00 PM'}],
#     'segments': []}]},
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'parent': {'id': '4d52b3d7a9dd2d4336bc06b4',
#   'name': 'Tomorrow Square (明天广场)',
#   'location': {'address': '399 Nanjing W Rd',
#    'crossStreet': 'at Huangpi N Rd',
#    'lat': 31.232454023838716,
#    'lng': 121.46515488624573,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 31.232454023838716,
#      'lng': 121.46515488624573}],
#    'cc': 'CN',
#    'city': 'Huangpu',
#    'state': '上海市',
#    'country': '中国',
#    'formattedAddress': ['399 Nanjing W Rd (at Huangpi N Rd)',
#     'Huangpu',
#     '上海市',
#     '中国']},
#   'categories': [{'id': '4bf58dd8d48988d130941735',
#     'name': 'Building',
#     'pluralName': 'Buildings',
#     'shortName': 'Building',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#      'suffix': '.png'},
#     'primary': True}]},
#  'hierarchy': [{'name': '明天广场 | Tomorrow Square',
#    'lang': 'US',
#    'id': '4d52b3d7a9dd2d4336bc06b4',
#    'canonicalUrl': 'https://foursquare.com/v/%E6%98%8E%E5%A4%A9%E5%B9%BF%E5%9C%BA--tomorrow-square/4d52b3d7a9dd2d4336bc06b4'}],
#  'attributes': {'groups': []},
#  'bestPhoto': {'id': '60685b0f58ba1d182d35ecd3',
#   'createdAt': 1617451791,
#   'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/8346567_IzkYGcru3e1gGdGKXFUjJwfY2wt2J3gIr2waHRh48E4.jpg',
#   'width': 1920,
#   'height': 1440,
#   'visibility': 'public'}}

# %% [markdown]
# ### B. Get the venue's overall rating

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %% [markdown]
# That is not a very good rating. Let's check the rating of the second closest Italian restaurant.

# %%
venue_id = '53bf3589498e13b13a0f3156' # ID of Conca Cucina Italian Restaurant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 8.0

# %% [markdown]
# Since this restaurant has no ratings, let's check the third restaurant.

# %%
# venue_id = '3fd66200f964a520f4e41ee3' # ID of Ecco
venue_id = '53bf3589498e13b13a0f3156' #BK

url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 8.0

# %% [markdown]
# Since this restaurant has a slightly better rating, let's explore it further.

# %% [markdown]
# ### C. Get the number of tips

# %%
result['response']['venue']['tips']['count']
# Out:
# 10

# %% [markdown]
# ### D. Get the venue's tips
#
# > `https://api.foursquare.com/v2/venues/`**VENUE_ID**`/tips?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&v=`**VERSION**`&limit=`**LIMIT**

# %% [markdown]
# #### Create URL and send GET request. Make sure to set limit to get all tips

# %%
## Ecco Tips
limit = 15 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&oauth_token={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60e3b8820c941651373da206'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'tips': {'count': 8,
#    'items': [{'id': '546ec9e5498e5e183f6f82de',
#      'createdAt': 1416546789,
#      'text': "Really good kebab in shanghai. They have two locations, I always had good kebabs at this location. A must try!! And don't forget the lunch deals :)",
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/546ec9e5498e5e183f6f82de',
#      'likes': {'count': 0, 'groups': []},
#      'like': False,
#      'logView': True,
#      'agreeCount': 1,
#      'disagreeCount': 0,
#      'todo': {'count': 0},
#      'user': {'id': '17548405',
#       'firstName': 'Selim',
#       'lastName': 'Gawad',
#       'gender': 'male',
#       'countryCode': 'CH',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/NGRQSWWDS5PIX5RB.jpg'}},
#      'authorInteractionType': 'liked'}]}}}

# %% [markdown]
# #### Get tips and list of associated features

# %%
tips = results['response']['tips']['items']

tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'canonicalUrl', 'likes', 'like', 'logView', 'agreeCount', 'disagreeCount', 'todo', 'user', 'authorInteractionType'])

# %% [markdown]
# #### Format column width and display all tips

# %%
pd.set_option('display.max_colwidth', None)

tips_df = pd.json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered.reindex()
# Out:
#                                                                                                                                                   text  \
# 0  Really good kebab in shanghai. They have two locations, I always had good kebabs at this location. A must try!! And don't forget the lunch deals :)
#
#    agreeCount  disagreeCount                        id user.firstName  \
# 0           1              0  546ec9e5498e5e183f6f82de          Selim
#
#   user.lastName   user.id
# 0         Gawad  17548405

# %% [markdown]
# Now remember that because we are using a personal developer account, then we can access only 2 of the restaurant's tips, instead of all 15 tips.

# %% [markdown]
# <a id="item3"></a>

# %% [markdown]
# ## 3. Search a Foursquare User
#
# > `https://api.foursquare.com/v2/users/`**USER_ID**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&v=`**VERSION**

# %% [markdown]
# ### Define URL, send GET request and display features associated with user

# %%
idnumber = '17548405' # user ID with most agree counts and complete profile
# idnumber = '475786006' #bk users
url = 'https://api.foursquare.com/v2/users/{}/?client_id={}&client_secret={}&oauth_token={}&v={}'.format(idnumber,CLIENT_ID, CLIENT_SECRET, ACCESS_TOKEN,VERSION) # define URL

# send GET request
results = requests.get(url).json()

user_data=results['response']['user']['photos']['items']

#results
pd.set_option('display.max_colwidth', None)

users_df = pd.json_normalize(user_data)
#This mainly used later to display the photo of the user
filtered_columns = ['id','prefix','suffix','width','height']
tips_filtered = users_df.loc[:, filtered_columns]
#url
tips_filtered
# Out:
#                          id                                prefix  \
# 0  546ec922498e625079c60e7f  https://fastly.4sqi.net/img/general/
#
#                                                       suffix  width  height
# 0  /17548405_J2hQgivjHpbj5RgkJwY7zPMeJyDdhtnS2b4ekWPJLwQ.jpg   1440    1920

# %%
g=tips_df.loc[tips_df['user.id'] == '17548405']
print('First Name: ' + tips_df['user.firstName'])
print('Last Name: ' + tips_df['user.lastName'])
# Out:
# 0    First Name: Selim
# Name: user.firstName, dtype: object
# 0    Last Name: Gawad
# Name: user.lastName, dtype: object

# %% [markdown]
# ### Retrieve the User's Profile Image

# %%
# 1. grab prefix of photo 
# 2. grab suffix of photo
# 3. concatenate them using the image size  
Image(url='https://fastly.4sqi.net/img/general/540x920/484542633_ELnUC1di2LwJTjPi04McysQZNqJHSCCSxS3i_GKGTEY.jpg')
# Out:
# <img src="https://fastly.4sqi.net/img/general/540x920/484542633_ELnUC1di2LwJTjPi04McysQZNqJHSCCSxS3i_GKGTEY.jpg"/>

# %% [markdown]
# Wow! So it turns out that Nick is a very active Foursquare user, with more than 250 tips.

# %% [markdown]
# ### Get User's tips

# %%
# define tips URL
user_id='17548405'
url = 'https://api.foursquare.com/v2/users/{}/tips?client_id={}&client_secret={}&oauth_token={}&v={}&limit={}'.format(user_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN,VERSION, limit)


# send GET request and get user's tips
results = requests.get(url).json()
tips = results['response']['tips']['items']

# format column width
pd.set_option('display.max_colwidth', None)

tips_df = pd.json_normalize(tips)

# # filter columns
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display user's tips
tips_filtered
# Out:
#                                                                                                                                                     text  \
# 0                                                                                                                 The califramboisilistic are the Best!!
# 1    Really good kebab in shanghai. They have two locations, I always had good kebabs at this location. A must try!! And don't forget the lunch deals :)
# 2                                                                              Burger deal on Monday! 2 burgers for 1. My favorite is the falafel burger
# 3  The cupcake framboisilistic is excellent!! It is filled with delicious raspberries and topped with white chocolate... A must try place for cupcakes!!
# 4                                                                                                                              Wifi password: vanillasky
# 5                                                                                Heures d’ouverture: Mardi - Vendredi: 8h00 à 19h00 Samedi: 9h00 à 18h00
# 6                                                                                                                          The best cupcake in Lausanne!
#
#    agreeCount  disagreeCount                        id
# 0           0              0  54ccd31b498eb3ebbecf0caf
# 1           1              0  546ec9e5498e5e183f6f82de
# 2           2              0  546ec91d498e4d2ca7b29314
# 3           4              0  54407b96498e039b9f35dff3
# 4           1              0  54118906498eb7d6db998c2f
# 5           1              0  4ee90bb06c25eda5a7d7aad2
# 6           2              0  4ee909da29c284f4bb66ac07

# %% [markdown]
# #### Let's get the venue for the tip with the greatest number of agree counts

# %%
tip_id = '5ab5575d73fe2516ad8f363b' # tip id

# define URL
url = 'https://api.foursquare.com/v2/users/{}/tips?client_id={}&client_secret={}&oauth_token={}&v={}'.format(idnumber, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION) # define URL


# send GET Request and examine results
result = requests.get(url).json()
print(result['response']['tips']['items'][0]['venue']['name'])
print(result['response']['tips']['items'][0]['venue']['location'])
# Out:
# Taïm
# {'address': '222 Waverly Pl', 'crossStreet': 'btwn Perry & W 11th St', 'lat': 40.735970102491926, 'lng': -74.00194019079207, 'labeledLatLngs': [{'label': 'display', 'lat': 40.735970102491926, 'lng': -74.00194019079207}, {'label': 'entrance', 'lat': 40.735887, 'lng': -74.001873}], 'postalCode': '10014', 'cc': 'US', 'neighborhood': 'West Village', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['222 Waverly Pl (btwn Perry & W 11th St)', 'New York, NY 10014']}

# %% [markdown]
# ## 4. Explore a location
#
# > `https://api.foursquare.com/v2/venues/`**explore**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**`&limit=`**LIMIT**

# %% [markdown]
# #### So, you just finished your gourmet dish at Ecco, and are just curious about the popular spots around the restaurant. In order to explore the area, let's start by getting the latitude and longitude values of Ecco Restaurant.

# %%
latitude = 40.715337
longitude = -74.008848

# %% [markdown]
# #### Define URL

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=EZH4ERBYQUEFWGXF300Z2F2MGAVYER22QXQL50PBV4PTO02B&client_secret=EJV41SURWZJNTRURBKEPEXQRT0JWWAOELP50MPUJHKBQSSBL&ll=40.715337,-74.008848&v=20180604&radius=1500&limit=30'

# %% [markdown]
# #### Send GET request and examine results

# %%
import requests

# %%
results = requests.get(url).json()
'There are {} around Ecco restaurant.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 30 around Ecco restaurant.'

# %% [markdown]
# #### Get relevant part of JSON

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '4af5d65ff964a52091fd21e3',
#   'name': 'Korin',
#   'location': {'address': '57 Warren St',
#    'crossStreet': 'Church St',
#    'lat': 40.71482437714839,
#    'lng': -74.00940425461492,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.71482437714839,
#      'lng': -74.00940425461492},
#     {'label': 'entrance', 'lat': 40.714727, 'lng': -74.009399}],
#    'distance': 73,
#    'postalCode': '10007',
#    'cc': 'US',
#    'neighborhood': 'Tribeca',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['57 Warren St (Church St)',
#     'New York, NY 10007',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1f8941735',
#     'name': 'Furniture / Home Store',
#     'pluralName': 'Furniture / Home Stores',
#     'shortName': 'Furniture / Home',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []},
#   'venuePage': {'id': '33104775'}},
#  'referralId': 'e-0-4af5d65ff964a52091fd21e3-0'}

# %% [markdown]
# #### Process JSON and convert it to a clean dataframe

# %%
dataframe = pd.json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
#                       name                     categories          address  \
# 0                    Korin         Furniture / Home Store     57 Warren St
# 1             Lekka Burger                   Burger Joint     81 Warren St
# 2          Los Tacos No. 1                     Taco Place    136 Church St
# 3  Philip Williams Posters                   Antique Shop  122 Chambers St
# 4                   Heyday                            Spa      92 Reade St
# 5         Takahachi Bakery                         Bakery     25 Murray St
# 6    Chambers Street Wines                      Wine Shop  148 Chambers St
# 7   Washington Market Park                     Playground     Greenwich St
# 8              Juice Press  Vegetarian / Vegan Restaurant     83 Murray St
# 9                Takahachi               Sushi Restaurant     145 Duane St
#
#                       crossStreet        lat        lng  \
# 0                       Church St  40.714824 -74.009404
# 1   btw Greenwich & West Broadway  40.715246 -74.010559
# 2                             NaN  40.714267 -74.008756
# 3                             NaN  40.715284 -74.008781
# 4                             NaN  40.715726 -74.007767
# 5                    at Church St  40.713653 -74.008804
# 6  btwn West Broadway & Hudson St  40.715773 -74.009718
# 7                     at Reade St  40.717046 -74.011095
# 8  btwn Greenwich St & W Broadway  40.714788 -74.011132
# 9     btwn W Broadway & Church St  40.716526 -74.008101
#
#                                                                                                                             labeledLatLngs  \
# 0  [{'label': 'display', 'lat': 40.71482437714839, 'lng': -74.00940425461492}, {'label': 'entrance', 'lat': 40.714727, 'lng': -74.009399}]
# 1                                                                              [{'label': 'display', 'lat': 40.715246, 'lng': -74.010559}]
# 2                                                                              [{'label': 'display', 'lat': 40.714267, 'lng': -74.008756}]
# 3  [{'label': 'display', 'lat': 40.71528423132827, 'lng': -74.00878093952018}, {'label': 'entrance', 'lat': 40.715188, 'lng': -74.008747}]
# 4                   [{'label': 'display', 'lat': 40.715726, 'lng': -74.007767}, {'label': 'entrance', 'lat': 40.715654, 'lng': -74.00782}]
# 5  [{'label': 'display', 'lat': 40.713652845301894, 'lng': -74.0088038953017}, {'label': 'entrance', 'lat': 40.713716, 'lng': -74.008443}]
# 6  [{'label': 'display', 'lat': 40.715773063928374, 'lng': -74.00971823312332}, {'label': 'entrance', 'lat': 40.715696, 'lng': -74.00988}]
# 7                                                              [{'label': 'display', 'lat': 40.71704598853704, 'lng': -74.01109457015991}]
# 8                                                               [{'label': 'display', 'lat': 40.71478769908051, 'lng': -74.0111317502157}]
# 9  [{'label': 'display', 'lat': 40.71652647412374, 'lng': -74.00810108466207}, {'label': 'entrance', 'lat': 40.716508, 'lng': -74.007989}]
#
#    distance postalCode  cc neighborhood      city state        country  \
# 0        73      10007  US      Tribeca  New York    NY  United States
# 1       144      10007  US          NaN  New York    NY  United States
# 2       119      10007  US          NaN  New York    NY  United States
# 3         8      10007  US          NaN  New York    NY  United States
# 4       100      10013  US          NaN  New York    NY  United States
# 5       187      10007  US          NaN  New York    NY  United States
# 6        88      10007  US          NaN  New York    NY  United States
# 7       268        NaN  US          NaN  New York    NY  United States
# 8       202      10007  US          NaN  New York    NY  United States
# 9       146      10013  US          NaN  New York    NY  United States
#
#                                                                         formattedAddress  \
# 0                          [57 Warren St (Church St), New York, NY 10007, United States]
# 1      [81 Warren St (btw Greenwich & West Broadway), New York, NY 10007, United States]
# 2                                     [136 Church St, New York, NY 10007, United States]
# 3                                   [122 Chambers St, New York, NY 10007, United States]
# 4                                       [92 Reade St, New York, NY 10013, United States]
# 5                       [25 Murray St (at Church St), New York, NY 10007, United States]
# 6  [148 Chambers St (btwn West Broadway & Hudson St), New York, NY 10007, United States]
# 7                              [Greenwich St (at Reade St), New York, NY, United States]
# 8     [83 Murray St (btwn Greenwich St & W Broadway), New York, NY 10007, United States]
# 9        [145 Duane St (btwn W Broadway & Church St), New York, NY 10013, United States]
#
#                          id
# 0  4af5d65ff964a52091fd21e3
# 1  5dc6f6a5ea8dfb00080f6faa
# 2  5d5f24ec09484500079aee00
# 3  4b747291f964a52042dd2de3
# 4  57ad129c498e05b086594d72
# 5  4c154c9a77cea593c401d260
# 6  4adcf23cf964a520cc6221e3
# 7  4a9bcc2ff964a5203b3520e3
# 8  54148bc6498ea7bb8c05b70a
# 9  4a8f2f39f964a520471420e3

# %% [markdown]
# #### Let's visualize these items on the map around our location

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


# add Ecco as a red circle mark
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Ecco',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_9c0684756b274b4c94f93e846d55b8fe%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_9c0684756b274b4c94f93e846d55b8fe%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_9c0684756b274b4c94f93e846d55b8fe%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_9c0684756b274b4c94f93e846d55b8fe%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B40.7149555%2C-74.0153365%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2015%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# <a id="item5"></a>

# %% [markdown]
# ## 5. Explore Trending Venues
#
# > `https://api.foursquare.com/v2/venues/`**trending**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**

# %% [markdown]
# #### Now, instead of simply exploring the area around Ecco, you are interested in knowing the venues that are trending at the time you are done with your lunch, meaning the places with the highest foot traffic. So let's do that and get the trending venues around Ecco.

# %%
# define URL
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# send GET request and get trending venues
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60e2d4a7dcceb40e0f7e2e8b'},
#  'response': {'venues': []}}

# %% [markdown]
# ### Check if any venues are trending at this time

# %%
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)

# %%
# display trending venues
trending_venues_df
# Out:
# 'No trending venues are available at the moment!'

# %% [markdown]
# Now, depending on when you run the above code, you might get different venues since the venues with the highest foot traffic are fetched live.

# %% [markdown]
# ### Visualize trending venues

# %%
if len(results['response']['venues']) == 0:
    venues_map = 'Cannot generate visual as no trending venues are available at the moment!'

else:
    venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


    # add Ecco as a red circle mark
    folium.CircleMarker(
        [latitude, longitude],
        radius=10,
        popup='Ecco',
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)


    # add the trending venues as blue circle markers
    for lat, lng, label in zip(trending_venues_df['location.lat'], trending_venues_df['location.lng'], trending_venues_df['name']):
        folium.CircleMarker(
            [lat, lng],
            radius=5,
            poup=label,
            fill=True,
            color='blue',
            fill_color='blue',
            fill_opacity=0.6
        ).add_to(venues_map)

# %%
# display map
venues_map
# Out:
# 'Cannot generate visual as no trending venues are available at the moment!'

# %% [markdown]
# <a id="item6"></a>

# %% [markdown]
# ### Thank you for completing this lab!
#
# This notebook was created by [Alex Aklson](https://www.linkedin.com/in/aklson?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork-21253531&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork-21253531&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ). I hope you found this lab interesting and educational. Feel free to contact me if you have any questions!
#
# This notebook modified by Nayef Abou Tayoun ([https://www.linkedin.com/in/nayefaboutayoun/](https://www.linkedin.com/in/nayefaboutayoun?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork-21253531&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ))

# %% [markdown]
# This notebook is part of a course on **Coursera** called _Applied Data Science Capstone_. If you accessed this notebook outside the course, you can take this course online by clicking [here](http://cocl.us/DP0701EN_Coursera_Week2_LAB1).

# %% [markdown]
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By    | Change Description                           |
# | ----------------- | ------- | ------------- | -------------------------------------------- |
# | 2021-03-17        | 2.1     | Lakshmi Holla | Changed the code for retreiving user profile |
# | 2020-11-26        | 2.0     | Lakshmi Holla | Updated the markdown cells                   |
# |                   |         |               |                                              |
# |                   |         |               |                                              |
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
